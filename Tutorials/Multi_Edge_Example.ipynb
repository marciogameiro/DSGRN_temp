# %%
import DSGRN

# %%
net_spec = 'x : (x + y)(y)\n y : (~z)(~z) \n z : ~x'

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of nodes in parameter graph:', parameter_graph.size())
# Out:
# Number of nodes in parameter graph: 148800

# %%
par_index = 132

# %%
parameter = parameter_graph.parameter(par_index)

# %% [markdown]
# To get the partial orders defining the parameter we can use one of the command below.

# %%
print(parameter.partialorders())
# Out:
# x : (t0, p0, p1, p4, t1, p2, p3, p5, p6, p7)
# y : (p0, p1, p2, p3, t0, t1)
# z : (p0, p1, t0, t1)

# %%
domain_graph = DSGRN.DomainGraph(parameter)

# %%
DSGRN.DrawGraph(domain_graph)

# %%
morse_decomposition = DSGRN.MorseDecomposition(domain_graph.digraph())

# %%
DSGRN.DrawGraph(morse_decomposition)

# %%
morse_graph = DSGRN.MorseGraph(domain_graph, morse_decomposition)

# %%
DSGRN.DrawGraph(morse_graph)

# %%
net_spec = 'x : (x + y)(~y)\n y : (z)(~z) \n z : ~x'

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of nodes in parameter graph:', parameter_graph.size())
# Out:
# Number of nodes in parameter graph: 148800

# %%
par_index = 527

# %%
parameter = parameter_graph.parameter(par_index)

# %%
print(parameter.partialorders())
# Out:
# x : (p0, p2, p4, t0, p6, t1, p1, p3, p5, p7)
# y : (p0, p1, t0, p2, p3, t1)
# z : (p0, p1, t0, t1)

# %%
domain_graph = DSGRN.DomainGraph(parameter)

# %%
DSGRN.DrawGraph(domain_graph)

# %%
morse_decomposition = DSGRN.MorseDecomposition(domain_graph.digraph())

# %%
DSGRN.DrawGraph(morse_decomposition)

# %%
morse_graph = DSGRN.MorseGraph(domain_graph, morse_decomposition)

# %%
DSGRN.DrawGraph(morse_graph)
