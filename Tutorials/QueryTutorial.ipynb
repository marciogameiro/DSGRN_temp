# %% [markdown]
# # DSGRN Query Functions

# %%
from DSGRN import *
database = Database("querytest.db")

# %%
database.parametergraph.dimension()
# Out:
# 3

# %% [markdown]
# We show here the network being considered in this example:

# %%
database

# %%
print(database.network.specification())
# Out:
# X1 : (X1)(~X3)
# X2 : X1
# X3 : (X1)(~X2)

# %% [markdown]
# # Query Overview
#
# In order to perform queries on the database sometimes preprocessing is necessary. In order to give a uniform approach to this we have adopted a design where each query corresponds to a python class whose name ends with the suffix `Query`. Each class has a constructor (i.e. `__init__` method) which accepts some arguments to indicate parameters of the query (e.g. which database).
#
# We currently have the following queries:
#
# | Name | Query Parameters | Query Input | Query Output |
# | ---- | ----------- | ------------ | --- |
# | MonostableQuery | Database | Morse Graph Index | True/False |
# | BistableQuery |  Database |  Morse Graph Index | True/False |
# | MultistableQuery |  Database | Morse Graph Index | True/False |
# | SingleGeneQuery | Database, Name of Network Node | Reduced Parameter Index | Annotated Factor Graph |
# | SingleFixedPointQuery |  Database, Domain Bounds |  Morse Graph Index | True/False |
# | DoubleFixedPointQuery |  Database, pair of Domain Bounds |  Morse Graph Index | True/False |
# | MonostableFixedPointQuery | Database, Domain Bounds |  Morse Graph Index | True/False |
# | InducibilityQuery | Database, Name of Network Node, pair of Domain Bounds | Reduced Parameter Index | Triple of True/False |
# | HysteresisQuery | Database, Name of Network Node, pair of Domain Bounds | Reduced Parameter Index | True/False |
#
# When the query object is constructed, it is passed the required parameters and any preprocessing that is required to support the query is done. In some cases the preprocessing is trivial, and in other cases it may be more extensive. After the object is constructed, it can be used to perform queries. This is accomplished by invoking the objects `__call__` operator (i.e. treating the object as a function). The call operator receives the query input and returns the query output. For example:
#
# ```
# single_gene_query = SingleGeneQuery(database, "X1")
# graph = single_gene_query(43)
# ```
#
# In the first line, the query object is created with the query parameters `database` and `"X1"`. This results in computation being done to organize a table in the database to quickly support "Single Gene Queries". The created object `single_gene_query` has a method `__call__` which allows it to be called as a function in order to produce query results. The input of the `__call__` method is a "reduced parameter index" and what is returned will be an annotated graph structure specific to what this query does.
#
# In many cases the input to the query is a Morse Graph Index and the output is a boolean value which indicates whether or not the morse graph index is in a precomputed set of matches. These query classes typically also support another method `matches` which simply returns the set of matches. This allows the following code:
#
# ```
# set_of_matches = SingleFixedPointQuery(database, domain_bounds).matches()
# ```
#
# In this code, a query object is created, the `matches` method is called and returns the set of matches, but no reference to the query object is kept. When using this paradigm one should be careful not to unnecessarily create the same query multiple times, or else the same preprocessing step would be repeated.

# %% [markdown]
# # MonostableQuery, BistableQuery, and MultistableQuery

# %%
monostable_query_object = MonostableQuery(database)
bistable_query_object = BistableQuery(database)
multistable_query_object = MultistableQuery(database)
# Out:
# 2021-03-26 11:38:17.836408:
# MonostableQuery :: initializing
# 2021-03-26 11:38:17.841783:
# MonostableQuery :: select MorseGraphIndex from (select MorseGraphIndex, count(*) as StableCount from (select MorseGraphIndex,Vertex from MorseGraphVertices except select MorseGraphIndex,Source from MorseGraphEdges) group by MorseGraphIndex) where StableCount=1;
# 2021-03-26 11:38:17.844806:
# MonostableQuery :: constructed

# %% [markdown]
# Evaluate the query on a few Morse Graph Indices:

# %%
monostable_query_object(0)
# Out:
# True

# %%
monostable_query_object(1)
# Out:
# False

# %% [markdown]
# How many matches for each type of query?

# %%
print([len(monostable_query_object.matches()), len(bistable_query_object.matches()), len(multistable_query_object.matches())])
# Out:
# [45, 98, 110]

# %% [markdown]
# Print the list of Morse graph indices which satisfy the monostable query.

# %%
print(monostable_query_object.matches())
# Out:
# frozenset({0, 2, 3, 130, 131, 6, 9, 10, 11, 18, 19, 20, 21, 146, 148, 25, 26, 153, 28, 30, 32, 34, 36, 38, 40, 43, 49, 50, 53, 55, 56, 59, 60, 74, 75, 78, 79, 89, 96, 102, 104, 113, 122, 123, 127})

# %% [markdown]
# Directly verify that all returns matches satisfy the corresponding query:

# %%
all( monostable_query_object(mgi) for mgi in monostable_query_object.matches() )
# Out:
# True

# %%
database.DrawMorseGraph(131)

# %% [markdown]
# # SingleGeneQuery
#
# Our interest is in fixing all combinatorial parameters except for the logic parameter corresponding to a single node and considering the set of parameters corresponding to this choice. Due to the factorization of the parameter graph, this set of parameters is isomorphic to the factor graph associated to the node of interest. In order to handle repeated queries efficiently, it is necessary to prepare a table which reorders information so that it is I/O efficient for algorithms to retrieve. The following does this:

# %%
single_gene_query = SingleGeneQuery(database, "X1")
# Out:
# 2021-03-26 11:38:19.277785:
# SingleGeneQuery(querytest.db, X1)
# 2021-03-26 11:38:19.291034:
# SingleGeneQuery: FactorGraph generated
# 2021-03-26 11:38:19.292047:
# SingleGeneQuery: SingleGeneQuery attribute missing from python database object.
# 2021-03-26 11:38:19.293239:
# SingleGeneQuery: SingleGeneQuery attributes created.
# 2021-03-26 11:38:19.294424:
# SingleGeneQuery: database structure unaware of gene X1
# 2021-03-26 11:38:19.295273:
# SingleGeneQuery: sanitized X1
# 2021-03-26 11:38:19.296485:
# SingleGeneQuery: cursor constructed
# 2021-03-26 11:38:19.300644:
# SingleGeneQuery: checked for table
# 2021-03-26 11:38:19.301877:
# SingleGeneQuery: added gene to python database object.
# 2021-03-26 11:38:19.302650:
# SingleGeneQuery: constructed

# %% [markdown]
# For a single gene query, the queries are graphs isomorphic to the factor graph, and the number of such queries corresponds to the number of "reduced parameter indices". This will be explained in more depth shortly. To help explain this we first examine the following computation:

# %%
N = single_gene_query.number_of_gene_parameters()
M = single_gene_query.number_of_reduced_parameters()
L = database.parametergraph.size()
print([N, M, N*M, L])
# Out:
# [50, 108, 5400, 5400]

# %% [markdown]
# Importantly, this factorization corresponds to a way to convert a parameter index (an integer) into a pair of integers, one in [0,50) and the other in [0,108), which we call the _gene parameter index_ and the _reduced parameter index_. The manner in which this is done is technical and has to do with how the integers encode combinatorial parameters using a mixed-radix system. Roughly speaking, the gene parameter index is obtained by extracting a digit from the mixed-radix representation of the parameter index, and what remains after removing the digit entirely (not just setting it to 0) is the reduced parameter index. This process can be reversed as well, so both the original parameter index and the (GeneParameterIndex, ReducedParameterIndex) pair are equivalent representations. What the prepare step we just accomplished did was create a table with the database's information which sorted the information by ReducedParameterIndex first and GeneParameterIndex second. (The original database sorts by ParameterIndex.)

# %% [markdown]
# ## Performing a single-gene query
#
# Now we perform a query. The result which the query returns is a graph. This graph contains data which has the raw information obtained from the query in the form of a python dictionary (i,e, `{key1:value1, key2:value2,...}`) where the keys are gene parameter indices, and the values are tuples `(hexcode, parameter index, morsegraphindex)`

# %%
graph = single_gene_query(43) # 43 is a "reduced parameter index"
# Out:
# 2021-03-26 11:38:19.321644:
# SingleGeneQuery(43)
# 2021-03-26 11:38:19.323655:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:19.324727:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:19.325784:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:19.326827:
# SingleGeneQuery: graph attributes emplaced

# %%
graph.data
# Out:
# {0: ('000', 2150, 28),
#  1: ('200', 2151, 28),
#  2: ('208', 2152, 28),
#  3: ('240', 2153, 40),
#  4: ('248', 2154, 40),
#  5: ('249', 2155, 40),
#  6: ('600', 2156, 35),
#  7: ('608', 2157, 35),
#  8: ('618', 2158, 35),
#  9: ('640', 2159, 94),
#  10: ('648', 2160, 94),
#  11: ('649', 2161, 94),
#  12: ('658', 2162, 94),
#  13: ('659', 2163, 94),
#  14: ('6C0', 2164, 36),
#  15: ('6C8', 2165, 36),
#  16: ('6C9', 2166, 36),
#  17: ('6D8', 2167, 36),
#  18: ('6D9', 2168, 36),
#  19: ('6DB', 2169, 36),
#  20: ('E00', 2170, 53),
#  21: ('E08', 2171, 53),
#  22: ('E18', 2172, 54),
#  23: ('E38', 2173, 58),
#  24: ('E40', 2174, 104),
#  25: ('E48', 2175, 104),
#  26: ('E49', 2176, 104),
#  27: ('E58', 2177, 105),
#  28: ('E59', 2178, 105),
#  29: ('E78', 2179, 106),
#  30: ('E79', 2180, 106),
#  31: ('EC0', 2181, 59),
#  32: ('EC8', 2182, 59),
#  33: ('EC9', 2183, 55),
#  34: ('ED8', 2184, 55),
#  35: ('ED9', 2185, 55),
#  36: ('EDB', 2186, 55),
#  37: ('EF8', 2187, 18),
#  38: ('EF9', 2188, 18),
#  39: ('EFB', 2189, 18),
#  40: ('FC0', 2190, 59),
#  41: ('FC8', 2191, 59),
#  42: ('FC9', 2192, 55),
#  43: ('FD8', 2193, 55),
#  44: ('FD9', 2194, 55),
#  45: ('FDB', 2195, 55),
#  46: ('FF8', 2196, 18),
#  47: ('FF9', 2197, 18),
#  48: ('FFB', 2198, 18),
#  49: ('FFF', 2199, 18)}

# %% [markdown]
# The query above returns the "MorseGraphIndex" which can be used with the database to retrieve the Morse graph. However we might only want to know if the Morse graph has a certain property. For example, we might want to know if it has 1 minimal node, or multiple (2 or more) minimal nodes. We create a function which takes a "MorseGraphIndex" and returns True if the associated Morse graph has multiple minimal nodes and False otherwise.

# %% [markdown]
# ## Visualizing the query
#
# The above information describes a partially ordered set. In this poset each node corresponds to a parameter index. Each parameter index corresponds to a pair of sub-indices called the "GeneParameterIndex" and the "ReducedParameterIndex" which are the integers resulting from splitting out the "digit" corresponding to the logic parameter of the gene of interest. The "GeneParameterIndex" corresponds directly to the logic parameter of the gene of interest which can also be represented with a "HexCode". Using the hex code representation we learn adjacency information (due to the GPG=CPG theorem). Since our query gives us all of this information, the query automatically determines this information and can display itself as a graph of the labelled poset corresponding to the query. It also comes equipped with some methods for checking graph properties (as we demonstrate later). The nodes themselves are labelled according to their "ParameterIndex" and "MorseGraphIndex":

# %%
graph

# %% [markdown]
# ## Features of the graph query
# In addition to being a graph there are other attributes of the query that are of use. In particular,
#
# The graph is as follows:
#
# * The vertices of the graph (`graph.vertices`) are named according to Gene Parameter Index (gpi).
# * `graph.edges` contains the directed edge p -> q iff p < q and the associated logic parameters are adjacent.
# * The graph is (by default) labelled with pairs (Parameter index, Morse graph index). The default graph labelling can be changed by replacing the `label` attribute with a new function. A `label` function takes the vertex name (i.e. gpi) as input and returns a label string.
# * The graph is (by default) colored blue. The default graph coloring can be changed by replacing teh `color` attribute with a new function. A `color` function takes the vertex name as an input and returns a new color string.
#
# In addition the following extra structures are provided:
#
# * `graph.data` is a dictionary from gene parameter index to (hex code, parameter index, morse graph index)
# * `graph.mgi` is a function which accepts a gpi and returns the associated Morse graph idnex
# * `graph.num_inputs` is the number of network edges which are inputs to the gene associated with the query
# * `graph.num_outputs`is the number of network edges which are outputs to the gene associated with the query
# * `graph.essential` is a boolean-valued function which determines if each vertex corresponds to an essential parameter node

# %% [markdown]
# ## Changing the color to inspect node properties
#
# In the above graph all the nodes have the same color. We can change this so that the color of the nodes reflects some property of our choosing. As an example, we might ask if a node has a Morse graph with multistability -- if so, we can color the node red, otherwise we can color the node blue. This is done as follows:

# %%
# Create a function which tells us if each vertex has the multistable property:
is_multistable = MultistableQuery(database)
# Change the coloring method of the graph to check for multistability:
graph.color = lambda v : "red" if is_multistable(v) else "blue"
# Display the graph:
graph

# %% [markdown]
# ## Testing the query result
#
# The above query indicates that some of the parameters associated with the query had multistability and some did not. In order to make sure everything is working properly, let's take an example of each class and draw the Morse graph. For instance, parameter index 2199 has Morse Graph 18, and is colored blue, which is supposed to correspond to a lack of multistability. We check this and find it is indeed the case:

# %%
database.DrawMorseGraph(18)

# %% [markdown]
# Similarly, our query result indicates parameter index 2180 corresponds to Morse Graph 84, which is colored red, indicated it _does_ exhibit multistability. We check this as well:

# %%
database.DrawMorseGraph(84)

# %% [markdown]
# # SingleFixedPointQuery, DoubleFixedPointQuery
#
# We have the capability to retrieve parameter indices for which a FP occurs in a certain location. We call these locations "domains". A domain can be indicated by which "bin" it corresponds to along each dimension. A bin is an interval bounded by either (a) consecutive thresholds in a given dimension, (b) between 0 and the first threshold, or (c) bounded below by the last threshold and unbounded above. In particular, for each dimension the number of thresholds is equal to the number of out-edges of the corresponding network node. If there are m such thresholds then there are m+1 locations (bins) along this dimension which we label 0, 1, 2, ..., m. This allows us to describe the location of a domain by listing bin numbers for each dimension.
#
# We can consider many domains at once which are grouped together in rectangular prisms. To represent these, we create a dictionary object where for each variable we product a key value pair where the key is the variable name and the value is a list of two integers [a,b] such that we mean that the variable can only occur in the bins between a and b (inclusive). If we omit a variable from the dictionary it is allowed to be in any bin. Also, if a=b we can simply write "a" instead of "[a,a]". For example:

# %%
bounds110 = {"X1":1,"X2":1,"X3":0} # Domain 1,1,0

# %%
bounds210 = {"X1":[2,2],"X2":[1,1],"X3":[0,1]}  # Domain 2,1,0 or Domain 2,1,1

# %%
bounds311 = {"X1":[3,3],"X2":[1,1],"X3":[1,1]} # Domain 3,1,1

# %% [markdown]
# Using these "bounds" variables to represent groups of domains, we can use query functions which ask for the collection of morse graphs which have an "FP" node labelled with a domain in those bounds. For example, to find the set of Morse Graph indices corresponding to fixed points in the region specified by "bounds110":

# %%
matches110 = SingleFixedPointQuery(database, bounds110).matches()
# Out:
# 2021-03-26 11:38:24.801402:
# SingleFixedPointQuery :: initializing
# 2021-03-26 11:38:24.806637:
# SingleFixedPointQuery :: calling MatchQuery
# 2021-03-26 11:38:24.808801:
# MatchQuery({'X1': 1, 'X2': 1, 'X3': 0}, Matches)
# 2021-03-26 11:38:24.810941:
# MatchQuery :: built expressions ["Label like 'FP { 1, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 0%'"]
# 2021-03-26 11:38:24.813198:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 1, _, _%';
# 2021-03-26 11:38:24.820971:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:24.824318:
# MatchQuery :: create temp table Matches as select * from tmpMatches2 where Label like 'FP { _, _, 0%';
# 2021-03-26 11:38:24.828054:
# MatchQuery :: constructed
# 2021-03-26 11:38:24.829777:
# SingleFixedPointQuery :: select MorseGraphIndex from Matches;
# 2021-03-26 11:38:24.830890:
# SingleFixedPointQuery :: drop table Matches;
# 2021-03-26 11:38:24.832317:
# SingleFixedPointQuery :: constructed

# %% [markdown]
# Find set of Morse Graph indices corresponding to fixed points in the region specified by "bounds210":

# %%
matches210 = SingleFixedPointQuery(database, bounds210).matches()
# Out:
# 2021-03-26 11:38:24.843469:
# SingleFixedPointQuery :: initializing
# 2021-03-26 11:38:24.844934:
# SingleFixedPointQuery :: calling MatchQuery
# 2021-03-26 11:38:24.846461:
# MatchQuery({'X1': [2, 2], 'X2': [1, 1], 'X3': [0, 1]}, Matches)
# 2021-03-26 11:38:24.849297:
# MatchQuery :: built expressions ["Label like 'FP { 2, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 0%' or Label like 'FP { _, _, 1%'"]
# 2021-03-26 11:38:24.853661:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 2, _, _%';
# 2021-03-26 11:38:24.855543:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:24.858092:
# MatchQuery :: create temp table Matches as select * from tmpMatches2 where Label like 'FP { _, _, 0%' or Label like 'FP { _, _, 1%';
# 2021-03-26 11:38:24.859825:
# MatchQuery :: constructed
# 2021-03-26 11:38:24.860900:
# SingleFixedPointQuery :: select MorseGraphIndex from Matches;
# 2021-03-26 11:38:24.863301:
# SingleFixedPointQuery :: drop table Matches;
# 2021-03-26 11:38:24.865939:
# SingleFixedPointQuery :: constructed

# %% [markdown]
# Find set of Morse Graph indices corresponding to fixed points in the region specified by "bounds311":

# %%
matches311 = SingleFixedPointQuery(database, bounds311).matches()
# Out:
# 2021-03-26 11:38:24.875990:
# SingleFixedPointQuery :: initializing
# 2021-03-26 11:38:24.877216:
# SingleFixedPointQuery :: calling MatchQuery
# 2021-03-26 11:38:24.879614:
# MatchQuery({'X1': [3, 3], 'X2': [1, 1], 'X3': [1, 1]}, Matches)
# 2021-03-26 11:38:24.881177:
# MatchQuery :: built expressions ["Label like 'FP { 3, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 1%'"]
# 2021-03-26 11:38:24.883614:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 3, _, _%';
# 2021-03-26 11:38:24.884952:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:24.886373:
# MatchQuery :: create temp table Matches as select * from tmpMatches2 where Label like 'FP { _, _, 1%';
# 2021-03-26 11:38:24.888247:
# MatchQuery :: constructed
# 2021-03-26 11:38:24.889070:
# SingleFixedPointQuery :: select MorseGraphIndex from Matches;
# 2021-03-26 11:38:24.890719:
# SingleFixedPointQuery :: drop table Matches;
# 2021-03-26 11:38:24.892467:
# SingleFixedPointQuery :: constructed

# %% [markdown]
# Find the set of Morse Graph indices with both a fixed point in 1,1,0 and a fixed point in 3,1,1:

# %%
matches_both = DoubleFixedPointQuery(database, bounds110,bounds311).matches()
# Out:
# 2021-03-26 11:38:24.901379:
# MatchQuery({'X1': 1, 'X2': 1, 'X3': 0}, Matches1)
# 2021-03-26 11:38:24.903000:
# MatchQuery :: built expressions ["Label like 'FP { 1, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 0%'"]
# 2021-03-26 11:38:24.904529:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 1, _, _%';
# 2021-03-26 11:38:24.906554:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:24.910377:
# MatchQuery :: create temp table Matches1 as select * from tmpMatches2 where Label like 'FP { _, _, 0%';
# 2021-03-26 11:38:24.912707:
# MatchQuery :: constructed
# 2021-03-26 11:38:24.915783:
# MatchQuery({'X1': [3, 3], 'X2': [1, 1], 'X3': [1, 1]}, Matches2)
# 2021-03-26 11:38:24.924658:
# MatchQuery :: built expressions ["Label like 'FP { 3, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 1%'"]
# 2021-03-26 11:38:24.927466:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 3, _, _%';
# 2021-03-26 11:38:24.948993:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:24.954289:
# MatchQuery :: create temp table Matches2 as select * from tmpMatches2 where Label like 'FP { _, _, 1%';
# 2021-03-26 11:38:24.955390:
# MatchQuery :: constructed

# %%
len(matches110), len(matches210), len(matches311), len(matches_both)
# Out:
# (19, 29, 20, 2)

# %%
matches_both
# Out:
# {106, 116}

# %% [markdown]
# ## Queries on Graph Properties
#
# It is possible to make queries about graph properties. If we have developed a set of queries about the vertices, we can ask several kinds of questions:
# 1) Does the minimal node have a certain property?
# 2) Does the maximal node have a certain property?
# 3) Must every path from the minimal node to the maximal node pass through a node with a certain property?
#
# We can even ask questions about how many paths from the minimal node to the maximal node have a certain property (or the fraction of paths).
#
# To help visualize the examples we color the graph "green", "blue", "red", and "yellow" according to each vertex's status with regard to the FP location query examples above. Specifically:

# %%
graph.color = lambda v : "green" if graph.mgi(v) in matches_both else ("blue" if graph.mgi(v) in matches210 else ( "yellow" if graph.mgi(v) in matches311 else "red"))

# %%
graph

# %%
minimum_gpi = 0
maximum_gpi = len(graph.vertices) - 1

# %% [markdown]
# ### Q1. Is the minimal node red?

# %%
graph.color(minimum_gpi) == "red"
# Out:
# True

# %% [markdown]
# ### Q2. Is the maximal node yellow?

# %%
graph.color(maximum_gpi) == "yellow"
# Out:
# True

# %% [markdown]
# ### Q3(a). Is there an essential green node?

# %%
any( graph.essential(v) and graph.color(v) == "green" for v in graph.vertices)
# Out:
# True

# %% [markdown]
# List all essential green nodes:

# %%
[v for v in graph.vertices if graph.essential(v) and graph.color(v) == "green"]
# Out:
# [29]

# %% [markdown]
# ### Q3(b). Does every path from min to max pass through green?

# %%
predicate = lambda v : graph.color(v) == "green"
graph.unavoidable(minimum_gpi,maximum_gpi,predicate)
# Out:
# False

# %% [markdown]
# No, they don't. What percentage of them pass through green?

# %%
subgraph = graph.subgraph(lambda v : not predicate(v))
number_missing_green = subgraph.numberOfPaths(minimum_gpi,maximum_gpi)
total_number = graph.numberOfPaths(minimum_gpi,maximum_gpi)
print(str((1.0 - float(number_missing_green)/float(total_number))*100.0) + "%")
# Out:
# 11.092985318107662%

# %% [markdown]
# ### Q3(b)'. Does every path from min to max pass through a blue vertex?

# %%
predicate = lambda v : graph.color(v) == "blue"
graph.unavoidable(minimum_gpi,maximum_gpi,predicate)
# Out:
# True

# %% [markdown]
# Which means there are zero paths from minimum to maximum in the subgraph where we take out the blue vertices, correct?

# %%
subgraph = graph.subgraph(lambda v : graph.color(v) != "blue")
if subgraph.numberOfPaths(minimum_gpi,maximum_gpi) == 0: print("Correct.")
# Out:
# Correct.

# %% [markdown]
# ### Q3(c). Is there an intermediate (neither max nor min) green node?

# %%
any( v != minimum_gpi and v != maximum_gpi and graph.color(v) == "green" for v in graph.vertices)
# Out:
# True

# %% [markdown]
# ## Visualizing the Essential parameter nodes:

# %%
graph.color = lambda v : "red" if graph.essential(v) else "green"
graph

# %% [markdown]
# # InducibilityQuery

# %%
inducibility_query_object = InducibilityQuery(database, "X1", bounds110, bounds311)
# Out:
# 2021-03-26 11:38:30.165531:
# MonostableFixedPointQuery :: initializing
# 2021-03-26 11:38:30.171411:
# SingleFixedPointQuery :: initializing
# 2021-03-26 11:38:30.173179:
# SingleFixedPointQuery :: calling MatchQuery
# 2021-03-26 11:38:30.175604:
# MatchQuery({'X1': 1, 'X2': 1, 'X3': 0}, Matches)
# 2021-03-26 11:38:30.183149:
# MatchQuery :: built expressions ["Label like 'FP { 1, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 0%'"]
# 2021-03-26 11:38:30.185513:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 1, _, _%';
# 2021-03-26 11:38:30.188743:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:30.190287:
# MatchQuery :: create temp table Matches as select * from tmpMatches2 where Label like 'FP { _, _, 0%';
# 2021-03-26 11:38:30.192103:
# MatchQuery :: constructed
# 2021-03-26 11:38:30.193058:
# SingleFixedPointQuery :: select MorseGraphIndex from Matches;
# 2021-03-26 11:38:30.194611:
# SingleFixedPointQuery :: drop table Matches;
# 2021-03-26 11:38:30.196880:
# SingleFixedPointQuery :: constructed
# 2021-03-26 11:38:30.197815:
# MonostableQuery :: initializing
# 2021-03-26 11:38:30.198615:
# MonostableQuery :: constructed
# 2021-03-26 11:38:30.201422:
# MonostableFixedPointQuery :: constructed
# 2021-03-26 11:38:30.202125:
# MonostableFixedPointQuery :: initializing
# 2021-03-26 11:38:30.205183:
# SingleFixedPointQuery :: initializing
# 2021-03-26 11:38:30.206412:
# SingleFixedPointQuery :: calling MatchQuery
# 2021-03-26 11:38:30.207292:
# MatchQuery({'X1': [3, 3], 'X2': [1, 1], 'X3': [1, 1]}, Matches)
# 2021-03-26 11:38:30.209004:
# MatchQuery :: built expressions ["Label like 'FP { 3, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 1%'"]
# 2021-03-26 11:38:30.209904:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 3, _, _%';
# 2021-03-26 11:38:30.214413:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:30.219481:
# MatchQuery :: create temp table Matches as select * from tmpMatches2 where Label like 'FP { _, _, 1%';
# 2021-03-26 11:38:30.222385:
# MatchQuery :: constructed
# 2021-03-26 11:38:30.224096:
# SingleFixedPointQuery :: select MorseGraphIndex from Matches;
# 2021-03-26 11:38:30.227697:
# SingleFixedPointQuery :: drop table Matches;
# 2021-03-26 11:38:30.230841:
# SingleFixedPointQuery :: constructed
# 2021-03-26 11:38:30.232487:
# MonostableQuery :: initializing
# 2021-03-26 11:38:30.233698:
# MonostableQuery :: constructed
# 2021-03-26 11:38:30.236078:
# MonostableFixedPointQuery :: constructed
# 2021-03-26 11:38:30.237149:
# MatchQuery({'X1': 1, 'X2': 1, 'X3': 0}, Matches1)
# 2021-03-26 11:38:30.239445:
# MatchQuery :: built expressions ["Label like 'FP { 1, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 0%'"]
# 2021-03-26 11:38:30.240379:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 1, _, _%';
# 2021-03-26 11:38:30.242481:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:30.246515:
# MatchQuery :: create temp table Matches1 as select * from tmpMatches2 where Label like 'FP { _, _, 0%';
# 2021-03-26 11:38:30.248286:
# MatchQuery :: constructed
# 2021-03-26 11:38:30.250025:
# MatchQuery({'X1': [3, 3], 'X2': [1, 1], 'X3': [1, 1]}, Matches2)
# 2021-03-26 11:38:30.251473:
# MatchQuery :: built expressions ["Label like 'FP { 3, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 1%'"]
# 2021-03-26 11:38:30.254586:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 3, _, _%';
# 2021-03-26 11:38:30.258856:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:30.261164:
# MatchQuery :: create temp table Matches2 as select * from tmpMatches2 where Label like 'FP { _, _, 1%';
# 2021-03-26 11:38:30.263491:
# MatchQuery :: constructed
# 2021-03-26 11:38:30.271088:
# SingleGeneQuery(querytest.db, X1)
# 2021-03-26 11:38:30.278707:
# SingleGeneQuery: FactorGraph generated
# 2021-03-26 11:38:30.279759:
# SingleGeneQuery: SingleGeneQuery attributes created.
# 2021-03-26 11:38:30.282408:
# SingleGeneQuery: constructed

# %%
reduced_parameters = range(inducibility_query_object.GeneQuery.number_of_reduced_parameters())

# %%
[ inducibility_query_object(rpi) for rpi in reduced_parameters ][0:10]
# Out:
# 2021-03-26 11:38:30.350106:
# SingleGeneQuery(0)
# 2021-03-26 11:38:30.373098:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.376019:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.387189:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.399502:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.403822:
# SingleGeneQuery(1)
# 2021-03-26 11:38:30.405776:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.407809:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.421185:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.423066:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.426723:
# SingleGeneQuery(2)
# 2021-03-26 11:38:30.429211:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.430699:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.431578:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.433967:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.435796:
# SingleGeneQuery(3)
# 2021-03-26 11:38:30.437403:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.439321:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.440789:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.442410:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.443246:
# SingleGeneQuery(4)
# 2021-03-26 11:38:30.445277:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.447674:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.450529:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.452890:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.454125:
# SingleGeneQuery(5)
# 2021-03-26 11:38:30.455116:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.457177:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.458231:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.459122:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.461325:
# SingleGeneQuery(6)
# 2021-03-26 11:38:30.463664:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.466364:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.469647:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.472658:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.475511:
# SingleGeneQuery(7)
# 2021-03-26 11:38:30.476885:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.479622:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.481635:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.483225:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.485281:
# SingleGeneQuery(8)
# 2021-03-26 11:38:30.486518:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.491274:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.492419:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.495413:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.497081:
# SingleGeneQuery(9)
# 2021-03-26 11:38:30.499760:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.501243:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.504215:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.507220:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.508622:
# SingleGeneQuery(10)
# 2021-03-26 11:38:30.509400:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.510669:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.511886:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.512478:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.519548:
# SingleGeneQuery(11)
# 2021-03-26 11:38:30.522364:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.524446:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.527173:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.528302:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.529886:
# SingleGeneQuery(12)
# 2021-03-26 11:38:30.531211:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.535230:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.539546:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.541275:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.544133:
# SingleGeneQuery(13)
# 2021-03-26 11:38:30.575266:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.584969:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.591960:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.600147:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.602922:
# SingleGeneQuery(14)
# 2021-03-26 11:38:30.612159:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.615015:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.616272:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.620678:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.624429:
# SingleGeneQuery(15)
# 2021-03-26 11:38:30.626547:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.635948:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.638910:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.640009:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.641707:
# SingleGeneQuery(16)
# 2021-03-26 11:38:30.642940:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.644192:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.645557:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.647069:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.648248:
# SingleGeneQuery(17)
# 2021-03-26 11:38:30.651227:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.655416:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.660705:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.662064:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.668278:
# SingleGeneQuery(18)
# 2021-03-26 11:38:30.677882:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.678817:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.704341:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.712266:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.723666:
# SingleGeneQuery(19)
# 2021-03-26 11:38:30.724455:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.726102:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.727788:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.729163:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.730635:
# SingleGeneQuery(20)
# 2021-03-26 11:38:30.732785:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.736138:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.741559:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.743856:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.745455:
# SingleGeneQuery(21)
# 2021-03-26 11:38:30.746332:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.747675:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.750838:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.752695:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.755669:
# SingleGeneQuery(22)
# 2021-03-26 11:38:30.763536:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.765182:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.767945:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.773403:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.774812:
# SingleGeneQuery(23)
# 2021-03-26 11:38:30.776152:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.777675:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.778547:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.781509:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.784828:
# SingleGeneQuery(24)
# 2021-03-26 11:38:30.787031:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.789062:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.791245:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.793007:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.794590:
# SingleGeneQuery(25)
# 2021-03-26 11:38:30.804034:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.810989:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.813586:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.824838:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.828820:
# SingleGeneQuery(26)
# 2021-03-26 11:38:30.833697:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.837244:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.842848:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.846016:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.848441:
# SingleGeneQuery(27)
# 2021-03-26 11:38:30.864069:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.870906:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.874864:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.879181:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.881666:
# SingleGeneQuery(28)
# 2021-03-26 11:38:30.893634:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.895287:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.897683:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.902105:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.904623:
# SingleGeneQuery(29)
# 2021-03-26 11:38:30.908687:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.911250:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.915650:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.924239:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.928099:
# SingleGeneQuery(30)
# 2021-03-26 11:38:30.928895:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.932669:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.940888:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.943947:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.945110:
# SingleGeneQuery(31)
# 2021-03-26 11:38:30.947114:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.959501:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.961164:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.965185:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.979116:
# SingleGeneQuery(32)
# 2021-03-26 11:38:30.983243:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.987017:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.989086:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.989835:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:30.991312:
# SingleGeneQuery(33)
# 2021-03-26 11:38:30.992712:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:30.994311:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:30.995981:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:30.998687:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.006178:
# SingleGeneQuery(34)
# 2021-03-26 11:38:31.010892:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.013733:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.016477:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.019872:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.021646:
# SingleGeneQuery(35)
# 2021-03-26 11:38:31.025997:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.030675:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.032202:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.035288:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.037910:
# SingleGeneQuery(36)
# 2021-03-26 11:38:31.041746:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.044656:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.051861:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.068426:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.070368:
# SingleGeneQuery(37)
# 2021-03-26 11:38:31.076081:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.078698:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.084109:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.086696:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.091899:
# SingleGeneQuery(38)
# 2021-03-26 11:38:31.093680:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.095133:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.097379:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.099914:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.103511:
# SingleGeneQuery(39)
# 2021-03-26 11:38:31.109330:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.112290:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.114647:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.120080:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.124164:
# SingleGeneQuery(40)
# 2021-03-26 11:38:31.126400:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.127653:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.133105:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.135051:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.139423:
# SingleGeneQuery(41)
# 2021-03-26 11:38:31.142818:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.146971:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.149025:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.151864:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.158800:
# SingleGeneQuery(42)
# 2021-03-26 11:38:31.161315:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.163688:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.166163:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.170543:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.176167:
# SingleGeneQuery(43)
# 2021-03-26 11:38:31.177530:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.193091:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.196846:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.204596:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.210818:
# SingleGeneQuery(44)
# 2021-03-26 11:38:31.212474:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.214275:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.215781:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.217182:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.219863:
# SingleGeneQuery(45)
# 2021-03-26 11:38:31.221416:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.224030:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.225431:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.227178:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.228121:
# SingleGeneQuery(46)
# 2021-03-26 11:38:31.229804:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.231620:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.237284:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.240636:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.243781:
# SingleGeneQuery(47)
# 2021-03-26 11:38:31.249614:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.251821:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.255078:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.261567:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.264831:
# SingleGeneQuery(48)
# 2021-03-26 11:38:31.268162:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.273786:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.275798:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.281404:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.283517:
# SingleGeneQuery(49)
# 2021-03-26 11:38:31.285779:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.287864:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.293038:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.295239:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.297532:
# SingleGeneQuery(50)
# 2021-03-26 11:38:31.329979:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.337923:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.362275:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.364639:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.366514:
# SingleGeneQuery(51)
# 2021-03-26 11:38:31.381980:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.384723:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.389177:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.399039:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.402244:
# SingleGeneQuery(52)
# 2021-03-26 11:38:31.404114:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.409794:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.413494:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.415314:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.417038:
# SingleGeneQuery(53)
# 2021-03-26 11:38:31.419097:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.421899:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.424058:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.425153:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.426905:
# SingleGeneQuery(54)
# 2021-03-26 11:38:31.429167:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.432511:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.435163:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.437104:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.441250:
# SingleGeneQuery(55)
# 2021-03-26 11:38:31.443205:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.445079:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.447202:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.448292:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.449360:
# SingleGeneQuery(56)
# 2021-03-26 11:38:31.450840:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.453306:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.454271:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.454898:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.455655:
# SingleGeneQuery(57)
# 2021-03-26 11:38:31.457774:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.459565:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.461867:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.463736:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.465925:
# SingleGeneQuery(58)
# 2021-03-26 11:38:31.467703:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.470529:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.471633:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.475656:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.479224:
# SingleGeneQuery(59)
# 2021-03-26 11:38:31.480451:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.482555:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.484229:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.489370:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.490265:
# SingleGeneQuery(60)
# 2021-03-26 11:38:31.493647:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.495731:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.497056:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.497766:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.505615:
# SingleGeneQuery(61)
# 2021-03-26 11:38:31.509998:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.515041:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.516989:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.518907:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.521114:
# SingleGeneQuery(62)
# 2021-03-26 11:38:31.528737:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.530218:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.531641:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.532898:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.533611:
# SingleGeneQuery(63)
# 2021-03-26 11:38:31.535374:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.538343:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.541174:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.542555:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.544899:
# SingleGeneQuery(64)
# 2021-03-26 11:38:31.546357:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.632389:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.644074:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.647113:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.648363:
# SingleGeneQuery(65)
# 2021-03-26 11:38:31.649829:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.654783:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.664278:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.671438:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.677634:
# SingleGeneQuery(66)
# 2021-03-26 11:38:31.678713:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.682509:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.694720:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.698157:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.699917:
# SingleGeneQuery(67)
# 2021-03-26 11:38:31.717375:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.722599:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.725794:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.730517:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.735351:
# SingleGeneQuery(68)
# 2021-03-26 11:38:31.737004:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.741272:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.742850:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.746524:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.755881:
# SingleGeneQuery(69)
# 2021-03-26 11:38:31.764938:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.768296:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.777720:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.781008:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.790262:
# SingleGeneQuery(70)
# 2021-03-26 11:38:31.793644:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.798309:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.802764:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.807101:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.810741:
# SingleGeneQuery(71)
# 2021-03-26 11:38:31.813047:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.818427:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.822015:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.825832:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.830314:
# SingleGeneQuery(72)
# 2021-03-26 11:38:31.833203:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.834839:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.839121:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.840802:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.842498:
# SingleGeneQuery(73)
# 2021-03-26 11:38:31.845478:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.847555:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.850036:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.854047:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.855468:
# SingleGeneQuery(74)
# 2021-03-26 11:38:31.857933:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.861264:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.862511:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.864200:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.865714:
# SingleGeneQuery(75)
# 2021-03-26 11:38:31.867807:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.870307:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.876135:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.877289:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.878624:
# SingleGeneQuery(76)
# 2021-03-26 11:38:31.880352:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.882522:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.884530:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.885719:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.888412:
# SingleGeneQuery(77)
# 2021-03-26 11:38:31.890113:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.892073:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.893958:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.897155:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.900212:
# SingleGeneQuery(78)
# 2021-03-26 11:38:31.912493:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.913741:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:31.914719:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:31.916927:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:31.919876:
# SingleGeneQuery(79)
# 2021-03-26 11:38:31.929055:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:31.994674:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.034205:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.113015:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.171946:
# SingleGeneQuery(80)
# 2021-03-26 11:38:32.177304:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.181601:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.183089:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.186802:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.189463:
# SingleGeneQuery(81)
# 2021-03-26 11:38:32.191507:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.192961:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.194256:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.195533:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.201072:
# SingleGeneQuery(82)
# 2021-03-26 11:38:32.202249:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.205370:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.207235:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.210911:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.214128:
# SingleGeneQuery(83)
# 2021-03-26 11:38:32.215624:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.216993:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.218527:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.224216:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.226015:
# SingleGeneQuery(84)
# 2021-03-26 11:38:32.228658:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.232729:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.234041:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.234940:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.236112:
# SingleGeneQuery(85)
# 2021-03-26 11:38:32.237689:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.241111:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.244205:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.247447:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.249383:
# SingleGeneQuery(86)
# 2021-03-26 11:38:32.251581:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.256975:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.262010:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.263902:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.265364:
# SingleGeneQuery(87)
# 2021-03-26 11:38:32.271448:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.272957:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.274468:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.276953:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.279745:
# SingleGeneQuery(88)
# 2021-03-26 11:38:32.281446:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.284882:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.285728:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.286700:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.290161:
# SingleGeneQuery(89)
# 2021-03-26 11:38:32.291371:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.292671:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.294950:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.327534:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.352885:
# SingleGeneQuery(90)
# 2021-03-26 11:38:32.355220:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.374681:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.376331:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.377862:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.378861:
# SingleGeneQuery(91)
# 2021-03-26 11:38:32.379746:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.384214:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.385930:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.395336:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.413719:
# SingleGeneQuery(92)
# 2021-03-26 11:38:32.421908:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.423965:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.425673:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.428178:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.429522:
# SingleGeneQuery(93)
# 2021-03-26 11:38:32.430941:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.434214:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.437405:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.440276:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.441241:
# SingleGeneQuery(94)
# 2021-03-26 11:38:32.442238:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.444274:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.444968:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.446318:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.447841:
# SingleGeneQuery(95)
# 2021-03-26 11:38:32.448926:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.450485:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.457575:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.459681:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.462148:
# SingleGeneQuery(96)
# 2021-03-26 11:38:32.465332:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.468468:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.469512:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.471781:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.473071:
# SingleGeneQuery(97)
# 2021-03-26 11:38:32.475171:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.479239:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.481406:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.483679:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.484707:
# SingleGeneQuery(98)
# 2021-03-26 11:38:32.486982:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.490086:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.492007:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.493620:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.497188:
# SingleGeneQuery(99)
# 2021-03-26 11:38:32.499723:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.502742:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.504577:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.505524:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.507134:
# SingleGeneQuery(100)
# 2021-03-26 11:38:32.509232:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.510974:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.512063:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.514728:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.516870:
# SingleGeneQuery(101)
# 2021-03-26 11:38:32.518206:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.521214:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.525405:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.528140:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.528998:
# SingleGeneQuery(102)
# 2021-03-26 11:38:32.532978:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.535092:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.535999:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.537701:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.540431:
# SingleGeneQuery(103)
# 2021-03-26 11:38:32.541472:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.544906:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.548683:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.549792:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.551309:
# SingleGeneQuery(104)
# 2021-03-26 11:38:32.552977:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.555131:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.556174:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.558726:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.560773:
# SingleGeneQuery(105)
# 2021-03-26 11:38:32.563944:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.566925:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.568854:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.569835:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.572402:
# SingleGeneQuery(106)
# 2021-03-26 11:38:32.573803:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.575778:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.576749:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.580947:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:32.582703:
# SingleGeneQuery(107)
# 2021-03-26 11:38:32.584102:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:32.587025:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:32.589362:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:32.601429:
# SingleGeneQuery: graph attributes emplaced
# [(False, False, False),
#  (False, False, False),
#  (False, False, False),
#  (False, False, False),
#  (False, False, False),
#  (False, False, False),
#  (False, False, False),
#  (False, True, False),
#  (False, True, False),
#  (False, False, False)]

# %% [markdown]
# # HysteresisQuery

# %%
hysteresis_query_object = HysteresisQuery(database, "X1", bounds110, bounds311)
# Out:
# 2021-03-26 11:38:32.660992:
# HysteresisQuery(querytest.db, X1)
# 2021-03-26 11:38:32.669254:
# HysteresisQuery :: MonostableFixedPointQuery(querytest.db, {'X1': 1, 'X2': 1, 'X3': 0})
# 2021-03-26 11:38:32.702327:
# MonostableFixedPointQuery :: initializing
# 2021-03-26 11:38:32.749409:
# SingleFixedPointQuery :: initializing
# 2021-03-26 11:38:32.751225:
# SingleFixedPointQuery :: calling MatchQuery
# 2021-03-26 11:38:32.797090:
# MatchQuery({'X1': 1, 'X2': 1, 'X3': 0}, Matches)
# 2021-03-26 11:38:32.804737:
# MatchQuery :: built expressions ["Label like 'FP { 1, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 0%'"]
# 2021-03-26 11:38:32.805921:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 1, _, _%';
# 2021-03-26 11:38:32.807621:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:32.809865:
# MatchQuery :: create temp table Matches as select * from tmpMatches2 where Label like 'FP { _, _, 0%';
# 2021-03-26 11:38:32.812587:
# MatchQuery :: constructed
# 2021-03-26 11:38:32.814517:
# SingleFixedPointQuery :: select MorseGraphIndex from Matches;
# 2021-03-26 11:38:32.817160:
# SingleFixedPointQuery :: drop table Matches;
# 2021-03-26 11:38:32.822559:
# SingleFixedPointQuery :: constructed
# 2021-03-26 11:38:32.829207:
# MonostableQuery :: initializing
# 2021-03-26 11:38:32.832122:
# MonostableQuery :: constructed
# 2021-03-26 11:38:32.833680:
# MonostableFixedPointQuery :: constructed
# 2021-03-26 11:38:32.836454:
# HysteresisQuery :: SingleFixedPointQuery(querytest.db, {'X1': 1, 'X2': 1, 'X3': 0})
# 2021-03-26 11:38:32.837627:
# SingleFixedPointQuery :: initializing
# 2021-03-26 11:38:32.840353:
# SingleFixedPointQuery :: calling MatchQuery
# 2021-03-26 11:38:32.841336:
# MatchQuery({'X1': 1, 'X2': 1, 'X3': 0}, Matches)
# 2021-03-26 11:38:32.842384:
# MatchQuery :: built expressions ["Label like 'FP { 1, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 0%'"]
# 2021-03-26 11:38:32.844020:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 1, _, _%';
# 2021-03-26 11:38:32.848229:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:32.852204:
# MatchQuery :: create temp table Matches as select * from tmpMatches2 where Label like 'FP { _, _, 0%';
# 2021-03-26 11:38:32.853845:
# MatchQuery :: constructed
# 2021-03-26 11:38:32.867161:
# SingleFixedPointQuery :: select MorseGraphIndex from Matches;
# 2021-03-26 11:38:32.869385:
# SingleFixedPointQuery :: drop table Matches;
# 2021-03-26 11:38:32.872071:
# SingleFixedPointQuery :: constructed
# 2021-03-26 11:38:32.873565:
# HysteresisQuery :: MonostableFixedPointQuery(querytest.db, {'X1': [3, 3], 'X2': [1, 1], 'X3': [1, 1]})
# 2021-03-26 11:38:32.874626:
# MonostableFixedPointQuery :: initializing
# 2021-03-26 11:38:32.875634:
# SingleFixedPointQuery :: initializing
# 2021-03-26 11:38:32.876928:
# SingleFixedPointQuery :: calling MatchQuery
# 2021-03-26 11:38:32.879322:
# MatchQuery({'X1': [3, 3], 'X2': [1, 1], 'X3': [1, 1]}, Matches)
# 2021-03-26 11:38:32.880434:
# MatchQuery :: built expressions ["Label like 'FP { 3, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 1%'"]
# 2021-03-26 11:38:32.883081:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 3, _, _%';
# 2021-03-26 11:38:32.885023:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:32.886665:
# MatchQuery :: create temp table Matches as select * from tmpMatches2 where Label like 'FP { _, _, 1%';
# 2021-03-26 11:38:32.889594:
# MatchQuery :: constructed
# 2021-03-26 11:38:32.891033:
# SingleFixedPointQuery :: select MorseGraphIndex from Matches;
# 2021-03-26 11:38:32.894829:
# SingleFixedPointQuery :: drop table Matches;
# 2021-03-26 11:38:32.899036:
# SingleFixedPointQuery :: constructed
# 2021-03-26 11:38:32.900463:
# MonostableQuery :: initializing
# 2021-03-26 11:38:32.902668:
# MonostableQuery :: constructed
# 2021-03-26 11:38:32.903996:
# MonostableFixedPointQuery :: constructed
# 2021-03-26 11:38:32.906175:
# HysteresisQuery :: SingleFixedPointQuery(querytest.db, {'X1': [3, 3], 'X2': [1, 1], 'X3': [1, 1]})
# 2021-03-26 11:38:32.908615:
# SingleFixedPointQuery :: initializing
# 2021-03-26 11:38:32.909434:
# SingleFixedPointQuery :: calling MatchQuery
# 2021-03-26 11:38:32.911961:
# MatchQuery({'X1': [3, 3], 'X2': [1, 1], 'X3': [1, 1]}, Matches)
# 2021-03-26 11:38:32.913839:
# MatchQuery :: built expressions ["Label like 'FP { 3, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 1%'"]
# 2021-03-26 11:38:32.917068:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 3, _, _%';
# 2021-03-26 11:38:32.919859:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:32.929799:
# MatchQuery :: create temp table Matches as select * from tmpMatches2 where Label like 'FP { _, _, 1%';
# 2021-03-26 11:38:32.946080:
# MatchQuery :: constructed
# 2021-03-26 11:38:32.949208:
# SingleFixedPointQuery :: select MorseGraphIndex from Matches;
# 2021-03-26 11:38:32.956161:
# SingleFixedPointQuery :: drop table Matches;
# 2021-03-26 11:38:32.970399:
# SingleFixedPointQuery :: constructed
# 2021-03-26 11:38:32.976886:
# HysteresisQuery :: DoubleFixedPointQuery(querytest.db, {'X1': 1, 'X2': 1, 'X3': 0}, {'X1': [3, 3], 'X2': [1, 1], 'X3': [1, 1]})
# 2021-03-26 11:38:32.981673:
# MatchQuery({'X1': 1, 'X2': 1, 'X3': 0}, Matches1)
# 2021-03-26 11:38:33.003919:
# MatchQuery :: built expressions ["Label like 'FP { 1, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 0%'"]
# 2021-03-26 11:38:33.012442:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 1, _, _%';
# 2021-03-26 11:38:33.016325:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:33.018301:
# MatchQuery :: create temp table Matches1 as select * from tmpMatches2 where Label like 'FP { _, _, 0%';
# 2021-03-26 11:38:33.019928:
# MatchQuery :: constructed
# 2021-03-26 11:38:33.020864:
# MatchQuery({'X1': [3, 3], 'X2': [1, 1], 'X3': [1, 1]}, Matches2)
# 2021-03-26 11:38:33.023432:
# MatchQuery :: built expressions ["Label like 'FP { 3, _, _%'", "Label like 'FP { _, 1, _%'", "Label like 'FP { _, _, 1%'"]
# 2021-03-26 11:38:33.026197:
# MatchQuery :: create temp table tmpMatches1 as select * from MorseGraphAnnotations where Label like 'FP { 3, _, _%';
# 2021-03-26 11:38:33.030385:
# MatchQuery :: create temp table tmpMatches2 as select * from tmpMatches1 where Label like 'FP { _, 1, _%';
# 2021-03-26 11:38:33.034739:
# MatchQuery :: create temp table Matches2 as select * from tmpMatches2 where Label like 'FP { _, _, 1%';
# 2021-03-26 11:38:33.037425:
# MatchQuery :: constructed
# 2021-03-26 11:38:33.040412:
# HysteresisQuery :: SingleGeneQuery(querytest.db, X1)
# 2021-03-26 11:38:33.043788:
# SingleGeneQuery(querytest.db, X1)
# 2021-03-26 11:38:33.052620:
# SingleGeneQuery: FactorGraph generated
# 2021-03-26 11:38:33.054028:
# SingleGeneQuery: SingleGeneQuery attributes created.
# 2021-03-26 11:38:33.055170:
# SingleGeneQuery: constructed

# %%
reduced_parameters = range(hysteresis_query_object.GeneQuery.number_of_reduced_parameters())

# %%
[ hysteresis_query_object(rpi) for rpi in reduced_parameters ][0:10]
# Out:
# 2021-03-26 11:38:33.080333:
# HysteresisQuery(0)
# 2021-03-26 11:38:33.083801:
# SingleGeneQuery(0)
# 2021-03-26 11:38:33.085841:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.086945:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.088637:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.092945:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.095332:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.098977:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:33.100344:
# HysteresisQuery: Alignment Graph has 0 vertices
# 2021-03-26 11:38:33.103879:
# HysteresisQuery: Alignment Graph has 0 edges
# 2021-03-26 11:38:33.105305:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:33.107778:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.109724:
# HysteresisQuery(1)
# 2021-03-26 11:38:33.110992:
# SingleGeneQuery(1)
# 2021-03-26 11:38:33.112525:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.115299:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.116398:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.117626:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.118530:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.119511:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.120557:
# HysteresisQuery(2)
# 2021-03-26 11:38:33.121157:
# SingleGeneQuery(2)
# 2021-03-26 11:38:33.122328:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.130924:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.135042:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.136447:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.137700:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.145372:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:33.147632:
# HysteresisQuery: Alignment Graph has 5 vertices
# 2021-03-26 11:38:33.149153:
# HysteresisQuery: Alignment Graph has 5 edges
# 2021-03-26 11:38:33.150960:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:33.154577:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.155285:
# HysteresisQuery(3)
# 2021-03-26 11:38:33.156354:
# SingleGeneQuery(3)
# 2021-03-26 11:38:33.160102:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.164493:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.169171:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.170233:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.182343:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.187865:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.211485:
# HysteresisQuery(4)
# 2021-03-26 11:38:33.212695:
# SingleGeneQuery(4)
# 2021-03-26 11:38:33.214369:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.216432:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.219791:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.223336:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.227540:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.229143:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.230746:
# HysteresisQuery(5)
# 2021-03-26 11:38:33.231865:
# SingleGeneQuery(5)
# 2021-03-26 11:38:33.232919:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.234956:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.236434:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.237746:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.242952:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.244812:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.247509:
# HysteresisQuery(6)
# 2021-03-26 11:38:33.250308:
# SingleGeneQuery(6)
# 2021-03-26 11:38:33.253513:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.255722:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.259744:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.262647:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.264919:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.266015:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.267381:
# HysteresisQuery(7)
# 2021-03-26 11:38:33.269747:
# SingleGeneQuery(7)
# 2021-03-26 11:38:33.271474:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.273388:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.275394:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.279330:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.281004:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.283919:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:33.285458:
# HysteresisQuery: Alignment Graph has 10 vertices
# 2021-03-26 11:38:33.286689:
# HysteresisQuery: Alignment Graph has 12 edges
# 2021-03-26 11:38:33.289298:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:33.293020:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.294512:
# HysteresisQuery(8)
# 2021-03-26 11:38:33.296355:
# SingleGeneQuery(8)
# 2021-03-26 11:38:33.297618:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.300863:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.301867:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.303971:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.308464:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.310695:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:33.313970:
# HysteresisQuery: Alignment Graph has 15 vertices
# 2021-03-26 11:38:33.319561:
# HysteresisQuery: Alignment Graph has 17 edges
# 2021-03-26 11:38:33.321688:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:33.324313:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.331196:
# HysteresisQuery(9)
# 2021-03-26 11:38:33.332343:
# SingleGeneQuery(9)
# 2021-03-26 11:38:33.337983:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.340175:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.341625:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.343023:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.344340:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.345889:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.347284:
# HysteresisQuery(10)
# 2021-03-26 11:38:33.348407:
# SingleGeneQuery(10)
# 2021-03-26 11:38:33.353889:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.357213:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.358815:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.359762:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.362799:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.363797:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.366759:
# HysteresisQuery(11)
# 2021-03-26 11:38:33.368039:
# SingleGeneQuery(11)
# 2021-03-26 11:38:33.369876:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.371231:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.373950:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.375743:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.378674:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.384203:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.387707:
# HysteresisQuery(12)
# 2021-03-26 11:38:33.388533:
# SingleGeneQuery(12)
# 2021-03-26 11:38:33.389968:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.395094:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.400478:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.405713:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.413746:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.422112:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.423866:
# HysteresisQuery(13)
# 2021-03-26 11:38:33.429181:
# SingleGeneQuery(13)
# 2021-03-26 11:38:33.437266:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.444775:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.447447:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.454635:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.455412:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.458366:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:33.467791:
# HysteresisQuery: Alignment Graph has 10 vertices
# 2021-03-26 11:38:33.469579:
# HysteresisQuery: Alignment Graph has 12 edges
# 2021-03-26 11:38:33.471752:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:33.475264:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.478939:
# HysteresisQuery(14)
# 2021-03-26 11:38:33.483113:
# SingleGeneQuery(14)
# 2021-03-26 11:38:33.486143:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.488788:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.490099:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.493340:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.495712:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.499506:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.500629:
# HysteresisQuery(15)
# 2021-03-26 11:38:33.501605:
# SingleGeneQuery(15)
# 2021-03-26 11:38:33.502535:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.503341:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.504714:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.506098:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.511040:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.515747:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.517998:
# HysteresisQuery(16)
# 2021-03-26 11:38:33.519542:
# SingleGeneQuery(16)
# 2021-03-26 11:38:33.522271:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.524140:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.525594:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.528328:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.531121:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.533311:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.535028:
# HysteresisQuery(17)
# 2021-03-26 11:38:33.536308:
# SingleGeneQuery(17)
# 2021-03-26 11:38:33.539299:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.544128:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.550357:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.575744:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.596110:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.598714:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.601615:
# HysteresisQuery(18)
# 2021-03-26 11:38:33.603064:
# SingleGeneQuery(18)
# 2021-03-26 11:38:33.604507:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.605777:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.608304:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.610268:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.614152:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.616810:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.618144:
# HysteresisQuery(19)
# 2021-03-26 11:38:33.619076:
# SingleGeneQuery(19)
# 2021-03-26 11:38:33.620909:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.622036:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.623508:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.626446:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.629435:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.634452:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.636666:
# HysteresisQuery(20)
# 2021-03-26 11:38:33.638739:
# SingleGeneQuery(20)
# 2021-03-26 11:38:33.640508:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.643340:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.650309:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.653350:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.656068:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.658119:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.660145:
# HysteresisQuery(21)
# 2021-03-26 11:38:33.661297:
# SingleGeneQuery(21)
# 2021-03-26 11:38:33.666612:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.668201:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.670095:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.672583:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.700258:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.701846:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.703696:
# HysteresisQuery(22)
# 2021-03-26 11:38:33.734150:
# SingleGeneQuery(22)
# 2021-03-26 11:38:33.766095:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.770329:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.782381:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.786511:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.800914:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.802682:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.804326:
# HysteresisQuery(23)
# 2021-03-26 11:38:33.806885:
# SingleGeneQuery(23)
# 2021-03-26 11:38:33.810451:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.813984:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.815265:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.816319:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.818054:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.819738:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.820855:
# HysteresisQuery(24)
# 2021-03-26 11:38:33.822413:
# SingleGeneQuery(24)
# 2021-03-26 11:38:33.823735:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.826193:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.828578:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.830914:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.835334:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.836606:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.838297:
# HysteresisQuery(25)
# 2021-03-26 11:38:33.839683:
# SingleGeneQuery(25)
# 2021-03-26 11:38:33.840954:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.842835:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.845506:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.852162:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.854083:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.855509:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.856435:
# HysteresisQuery(26)
# 2021-03-26 11:38:33.858600:
# SingleGeneQuery(26)
# 2021-03-26 11:38:33.859378:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.862804:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.867253:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.868814:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.870711:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.872369:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.873761:
# HysteresisQuery(27)
# 2021-03-26 11:38:33.875013:
# SingleGeneQuery(27)
# 2021-03-26 11:38:33.878277:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.885812:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.887544:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.888824:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.890149:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.891624:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.892813:
# HysteresisQuery(28)
# 2021-03-26 11:38:33.894264:
# SingleGeneQuery(28)
# 2021-03-26 11:38:33.896502:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.901431:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.904137:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.906975:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.909036:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.911154:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.916532:
# HysteresisQuery(29)
# 2021-03-26 11:38:33.918843:
# SingleGeneQuery(29)
# 2021-03-26 11:38:33.920302:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.922103:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.931556:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.956650:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.957680:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.973408:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.975177:
# HysteresisQuery(30)
# 2021-03-26 11:38:33.978158:
# SingleGeneQuery(30)
# 2021-03-26 11:38:33.979025:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.982728:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:33.984199:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:33.985889:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:33.987139:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:33.988190:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:33.989803:
# HysteresisQuery(31)
# 2021-03-26 11:38:33.990806:
# SingleGeneQuery(31)
# 2021-03-26 11:38:33.994083:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:33.996027:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.001766:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.004217:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.005402:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.006187:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.010718:
# HysteresisQuery(32)
# 2021-03-26 11:38:34.013670:
# SingleGeneQuery(32)
# 2021-03-26 11:38:34.015526:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.018481:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.019881:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.021298:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.021963:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.023403:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.024178:
# HysteresisQuery(33)
# 2021-03-26 11:38:34.025688:
# SingleGeneQuery(33)
# 2021-03-26 11:38:34.028464:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.029989:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.032218:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.034654:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.035780:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.037712:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.038871:
# HysteresisQuery(34)
# 2021-03-26 11:38:34.039863:
# SingleGeneQuery(34)
# 2021-03-26 11:38:34.041325:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.044279:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.047089:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.048998:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.050263:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.052015:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.054198:
# HysteresisQuery(35)
# 2021-03-26 11:38:34.055514:
# SingleGeneQuery(35)
# 2021-03-26 11:38:34.059014:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.060303:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.062055:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.068868:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.070654:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.072914:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.073646:
# HysteresisQuery(36)
# 2021-03-26 11:38:34.076322:
# SingleGeneQuery(36)
# 2021-03-26 11:38:34.079956:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.087292:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.091085:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.120046:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.122656:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.127893:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.128739:
# HysteresisQuery(37)
# 2021-03-26 11:38:34.129974:
# SingleGeneQuery(37)
# 2021-03-26 11:38:34.135344:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.141959:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.143886:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.144909:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.149494:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.156463:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:34.172592:
# HysteresisQuery: Alignment Graph has 15 vertices
# 2021-03-26 11:38:34.202375:
# HysteresisQuery: Alignment Graph has 23 edges
# 2021-03-26 11:38:34.206096:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:34.210319:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.214052:
# HysteresisQuery(38)
# 2021-03-26 11:38:34.215163:
# SingleGeneQuery(38)
# 2021-03-26 11:38:34.219110:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.222002:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.224343:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.226162:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.228236:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.232823:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.235411:
# HysteresisQuery(39)
# 2021-03-26 11:38:34.237760:
# SingleGeneQuery(39)
# 2021-03-26 11:38:34.240768:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.241956:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.247050:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.253147:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.255978:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.257292:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.258613:
# HysteresisQuery(40)
# 2021-03-26 11:38:34.260432:
# SingleGeneQuery(40)
# 2021-03-26 11:38:34.261748:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.265758:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.270813:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.274653:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.276849:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.284307:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.289313:
# HysteresisQuery(41)
# 2021-03-26 11:38:34.290655:
# SingleGeneQuery(41)
# 2021-03-26 11:38:34.293408:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.294825:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.302642:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.308640:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.315639:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.319458:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.331967:
# HysteresisQuery(42)
# 2021-03-26 11:38:34.340682:
# SingleGeneQuery(42)
# 2021-03-26 11:38:34.341941:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.344314:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.346488:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.356484:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.365136:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.369220:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.370662:
# HysteresisQuery(43)
# 2021-03-26 11:38:34.371914:
# SingleGeneQuery(43)
# 2021-03-26 11:38:34.374449:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.376353:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.386899:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.388916:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.391952:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.395205:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:34.396347:
# HysteresisQuery: Alignment Graph has 23 vertices
# 2021-03-26 11:38:34.403969:
# HysteresisQuery: Alignment Graph has 33 edges
# 2021-03-26 11:38:34.406134:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:34.406914:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.408498:
# HysteresisQuery(44)
# 2021-03-26 11:38:34.409753:
# SingleGeneQuery(44)
# 2021-03-26 11:38:34.423872:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.429200:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.431097:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.437295:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.437989:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.439931:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.440987:
# HysteresisQuery(45)
# 2021-03-26 11:38:34.441877:
# SingleGeneQuery(45)
# 2021-03-26 11:38:34.447228:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.455410:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.457619:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.459160:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.461356:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.463534:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.464987:
# HysteresisQuery(46)
# 2021-03-26 11:38:34.468008:
# SingleGeneQuery(46)
# 2021-03-26 11:38:34.472939:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.474475:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.476675:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.479992:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.482636:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.490965:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:34.495697:
# HysteresisQuery: Alignment Graph has 15 vertices
# 2021-03-26 11:38:34.497842:
# HysteresisQuery: Alignment Graph has 23 edges
# 2021-03-26 11:38:34.500646:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:34.504377:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.507607:
# HysteresisQuery(47)
# 2021-03-26 11:38:34.508742:
# SingleGeneQuery(47)
# 2021-03-26 11:38:34.511849:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.514469:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.523524:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.527180:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.529239:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.530537:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.534419:
# HysteresisQuery(48)
# 2021-03-26 11:38:34.536364:
# SingleGeneQuery(48)
# 2021-03-26 11:38:34.539910:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.542905:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.545776:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.547244:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.565410:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.581645:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.593682:
# HysteresisQuery(49)
# 2021-03-26 11:38:34.595243:
# SingleGeneQuery(49)
# 2021-03-26 11:38:34.598705:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.607246:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.608951:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.612521:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.614161:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.616812:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:34.619768:
# HysteresisQuery: Alignment Graph has 23 vertices
# 2021-03-26 11:38:34.621308:
# HysteresisQuery: Alignment Graph has 33 edges
# 2021-03-26 11:38:34.624438:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:34.626173:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.629563:
# HysteresisQuery(50)
# 2021-03-26 11:38:34.631549:
# SingleGeneQuery(50)
# 2021-03-26 11:38:34.632921:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.636287:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.639892:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.641814:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.643704:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.644954:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.646396:
# HysteresisQuery(51)
# 2021-03-26 11:38:34.647178:
# SingleGeneQuery(51)
# 2021-03-26 11:38:34.647967:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.649995:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.652176:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.653496:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.654265:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.656093:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.659933:
# HysteresisQuery(52)
# 2021-03-26 11:38:34.662037:
# SingleGeneQuery(52)
# 2021-03-26 11:38:34.663058:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.668561:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.671669:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.709451:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.722022:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.724953:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:34.726415:
# HysteresisQuery: Alignment Graph has 10 vertices
# 2021-03-26 11:38:34.730191:
# HysteresisQuery: Alignment Graph has 12 edges
# 2021-03-26 11:38:34.731830:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:34.734113:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.755923:
# HysteresisQuery(53)
# 2021-03-26 11:38:34.757334:
# SingleGeneQuery(53)
# 2021-03-26 11:38:34.764402:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.766413:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.767636:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.771636:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.774648:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.776391:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.780435:
# HysteresisQuery(54)
# 2021-03-26 11:38:34.781682:
# SingleGeneQuery(54)
# 2021-03-26 11:38:34.783552:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.785521:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.787460:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.789605:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.790926:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.792416:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.794588:
# HysteresisQuery(55)
# 2021-03-26 11:38:34.799936:
# SingleGeneQuery(55)
# 2021-03-26 11:38:34.802182:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.807494:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.821594:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.828675:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.834843:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.839526:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:34.842304:
# HysteresisQuery: Alignment Graph has 15 vertices
# 2021-03-26 11:38:34.846502:
# HysteresisQuery: Alignment Graph has 23 edges
# 2021-03-26 11:38:34.852132:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:34.854020:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.865311:
# HysteresisQuery(56)
# 2021-03-26 11:38:34.871854:
# SingleGeneQuery(56)
# 2021-03-26 11:38:34.874478:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.876476:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.880349:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.888583:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.892315:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.893748:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.897284:
# HysteresisQuery(57)
# 2021-03-26 11:38:34.899283:
# SingleGeneQuery(57)
# 2021-03-26 11:38:34.903403:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.907123:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.908876:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.909893:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.912210:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:34.914240:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:34.915914:
# HysteresisQuery(58)
# 2021-03-26 11:38:34.918138:
# SingleGeneQuery(58)
# 2021-03-26 11:38:34.920014:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:34.922265:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:34.955611:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:34.981889:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:34.988115:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.003799:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.005314:
# HysteresisQuery(59)
# 2021-03-26 11:38:35.008488:
# SingleGeneQuery(59)
# 2021-03-26 11:38:35.012460:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.014119:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.015071:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.016895:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.020554:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.023500:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.024754:
# HysteresisQuery(60)
# 2021-03-26 11:38:35.027550:
# SingleGeneQuery(60)
# 2021-03-26 11:38:35.037269:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.039496:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.042503:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.043623:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.045566:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.046502:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.047634:
# HysteresisQuery(61)
# 2021-03-26 11:38:35.050496:
# SingleGeneQuery(61)
# 2021-03-26 11:38:35.056687:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.058187:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.060005:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.061370:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.068008:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.071450:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:35.074551:
# HysteresisQuery: Alignment Graph has 23 vertices
# 2021-03-26 11:38:35.080087:
# HysteresisQuery: Alignment Graph has 33 edges
# 2021-03-26 11:38:35.081069:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:35.083777:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.085582:
# HysteresisQuery(62)
# 2021-03-26 11:38:35.088221:
# SingleGeneQuery(62)
# 2021-03-26 11:38:35.091660:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.094156:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.095506:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.096322:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.097600:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.103742:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.105989:
# HysteresisQuery(63)
# 2021-03-26 11:38:35.107474:
# SingleGeneQuery(63)
# 2021-03-26 11:38:35.109590:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.112616:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.113924:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.114993:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.115518:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.117204:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.118527:
# HysteresisQuery(64)
# 2021-03-26 11:38:35.119331:
# SingleGeneQuery(64)
# 2021-03-26 11:38:35.120797:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.123112:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.124787:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.127886:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.130658:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.135026:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:35.137495:
# HysteresisQuery: Alignment Graph has 15 vertices
# 2021-03-26 11:38:35.139098:
# HysteresisQuery: Alignment Graph has 23 edges
# 2021-03-26 11:38:35.140238:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:35.140737:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.141619:
# HysteresisQuery(65)
# 2021-03-26 11:38:35.146870:
# SingleGeneQuery(65)
# 2021-03-26 11:38:35.148050:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.149068:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.149699:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.151252:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.151912:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.154574:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.155962:
# HysteresisQuery(66)
# 2021-03-26 11:38:35.158814:
# SingleGeneQuery(66)
# 2021-03-26 11:38:35.160913:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.162655:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.163946:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.165208:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.167316:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.170976:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.173826:
# HysteresisQuery(67)
# 2021-03-26 11:38:35.176615:
# SingleGeneQuery(67)
# 2021-03-26 11:38:35.179020:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.190189:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.194640:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.220970:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.229627:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.247234:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:35.256881:
# HysteresisQuery: Alignment Graph has 23 vertices
# 2021-03-26 11:38:35.259946:
# HysteresisQuery: Alignment Graph has 33 edges
# 2021-03-26 11:38:35.263678:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:35.273881:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.275045:
# HysteresisQuery(68)
# 2021-03-26 11:38:35.276871:
# SingleGeneQuery(68)
# 2021-03-26 11:38:35.278150:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.280005:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.282547:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.284278:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.286220:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.287419:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.289089:
# HysteresisQuery(69)
# 2021-03-26 11:38:35.290310:
# SingleGeneQuery(69)
# 2021-03-26 11:38:35.293147:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.294629:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.298393:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.302657:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.304356:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.306436:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.309231:
# HysteresisQuery(70)
# 2021-03-26 11:38:35.309763:
# SingleGeneQuery(70)
# 2021-03-26 11:38:35.310879:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.313290:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.316828:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.325744:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.326764:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.337277:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:35.339679:
# HysteresisQuery: Alignment Graph has 10 vertices
# 2021-03-26 11:38:35.343403:
# HysteresisQuery: Alignment Graph has 12 edges
# 2021-03-26 11:38:35.356781:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:35.360045:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.361233:
# HysteresisQuery(71)
# 2021-03-26 11:38:35.363113:
# SingleGeneQuery(71)
# 2021-03-26 11:38:35.373832:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.376761:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.383475:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.387990:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.393994:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.396865:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.400026:
# HysteresisQuery(72)
# 2021-03-26 11:38:35.405879:
# SingleGeneQuery(72)
# 2021-03-26 11:38:35.408257:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.413899:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.416771:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.419901:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.421735:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.433676:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.443093:
# HysteresisQuery(73)
# 2021-03-26 11:38:35.444224:
# SingleGeneQuery(73)
# 2021-03-26 11:38:35.445608:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.451389:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.468918:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.474711:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.477618:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.479895:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.488447:
# HysteresisQuery(74)
# 2021-03-26 11:38:35.491603:
# SingleGeneQuery(74)
# 2021-03-26 11:38:35.494085:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.495996:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.500583:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.503186:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.504662:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.510204:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.513344:
# HysteresisQuery(75)
# 2021-03-26 11:38:35.515375:
# SingleGeneQuery(75)
# 2021-03-26 11:38:35.520763:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.523067:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.525700:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.527712:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.528990:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.530153:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.532676:
# HysteresisQuery(76)
# 2021-03-26 11:38:35.534283:
# SingleGeneQuery(76)
# 2021-03-26 11:38:35.542982:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.547852:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.557989:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.640315:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.641701:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.645624:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.658294:
# HysteresisQuery(77)
# 2021-03-26 11:38:35.662130:
# SingleGeneQuery(77)
# 2021-03-26 11:38:35.675252:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.676988:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.680489:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.682074:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.683851:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.686624:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.688099:
# HysteresisQuery(78)
# 2021-03-26 11:38:35.690752:
# SingleGeneQuery(78)
# 2021-03-26 11:38:35.692337:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.693566:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.694603:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.695747:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.697409:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.698320:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.699944:
# HysteresisQuery(79)
# 2021-03-26 11:38:35.700899:
# SingleGeneQuery(79)
# 2021-03-26 11:38:35.703064:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.703868:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.704493:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.706340:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.706843:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.708010:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:35.708764:
# HysteresisQuery: Alignment Graph has 10 vertices
# 2021-03-26 11:38:35.709305:
# HysteresisQuery: Alignment Graph has 12 edges
# 2021-03-26 11:38:35.709821:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:35.710418:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.710856:
# HysteresisQuery(80)
# 2021-03-26 11:38:35.711709:
# SingleGeneQuery(80)
# 2021-03-26 11:38:35.716300:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.721480:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.722721:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.723257:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.723786:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.724385:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.724864:
# HysteresisQuery(81)
# 2021-03-26 11:38:35.725670:
# SingleGeneQuery(81)
# 2021-03-26 11:38:35.729627:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.731755:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.737456:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.740290:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.742136:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.743538:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.744980:
# HysteresisQuery(82)
# 2021-03-26 11:38:35.746246:
# SingleGeneQuery(82)
# 2021-03-26 11:38:35.750786:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.752774:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.755853:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.757327:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.758288:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.761011:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.762325:
# HysteresisQuery(83)
# 2021-03-26 11:38:35.766239:
# SingleGeneQuery(83)
# 2021-03-26 11:38:35.769746:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.777630:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.778429:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.784285:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.785970:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.788086:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.789585:
# HysteresisQuery(84)
# 2021-03-26 11:38:35.790683:
# SingleGeneQuery(84)
# 2021-03-26 11:38:35.791625:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.794397:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.795623:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.796759:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.808700:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.834939:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.844494:
# HysteresisQuery(85)
# 2021-03-26 11:38:35.851405:
# SingleGeneQuery(85)
# 2021-03-26 11:38:35.856332:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.859682:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.861377:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.863967:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.865855:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.867537:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.869105:
# HysteresisQuery(86)
# 2021-03-26 11:38:35.871502:
# SingleGeneQuery(86)
# 2021-03-26 11:38:35.873535:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.874268:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.874855:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.877064:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.879236:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.880754:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.882632:
# HysteresisQuery(87)
# 2021-03-26 11:38:35.885043:
# SingleGeneQuery(87)
# 2021-03-26 11:38:35.886143:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.891036:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.894452:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.896715:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.899636:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.901805:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.903534:
# HysteresisQuery(88)
# 2021-03-26 11:38:35.904672:
# SingleGeneQuery(88)
# 2021-03-26 11:38:35.906992:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.908226:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.910507:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.911437:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.913404:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:35.917852:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:35.920912:
# HysteresisQuery(89)
# 2021-03-26 11:38:35.924867:
# SingleGeneQuery(89)
# 2021-03-26 11:38:35.930336:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:35.942846:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:35.944085:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:35.960920:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:35.964575:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.002300:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.003459:
# HysteresisQuery(90)
# 2021-03-26 11:38:36.007196:
# SingleGeneQuery(90)
# 2021-03-26 11:38:36.024363:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.029753:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.032388:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.047443:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.064241:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.071759:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.080554:
# HysteresisQuery(91)
# 2021-03-26 11:38:36.083337:
# SingleGeneQuery(91)
# 2021-03-26 11:38:36.089735:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.092296:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.094693:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.096698:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.104724:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.124013:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.128731:
# HysteresisQuery(92)
# 2021-03-26 11:38:36.130241:
# SingleGeneQuery(92)
# 2021-03-26 11:38:36.138535:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.141565:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.144512:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.145948:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.147596:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.149485:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.154371:
# HysteresisQuery(93)
# 2021-03-26 11:38:36.164201:
# SingleGeneQuery(93)
# 2021-03-26 11:38:36.170246:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.172724:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.212244:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.242067:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.244492:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.247015:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.257539:
# HysteresisQuery(94)
# 2021-03-26 11:38:36.277819:
# SingleGeneQuery(94)
# 2021-03-26 11:38:36.280384:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.287943:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.291718:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.295571:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.298136:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.301520:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.304483:
# HysteresisQuery(95)
# 2021-03-26 11:38:36.307321:
# SingleGeneQuery(95)
# 2021-03-26 11:38:36.311415:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.312717:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.314319:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.315928:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.319828:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.321621:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.323184:
# HysteresisQuery(96)
# 2021-03-26 11:38:36.327235:
# SingleGeneQuery(96)
# 2021-03-26 11:38:36.328525:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.334025:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.335567:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.337704:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.343524:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.346622:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.348454:
# HysteresisQuery(97)
# 2021-03-26 11:38:36.349147:
# SingleGeneQuery(97)
# 2021-03-26 11:38:36.350179:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.351938:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.357684:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.361041:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.363258:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.366832:
# HysteresisQuery: Alignment Graph Constructed.
# 2021-03-26 11:38:36.370488:
# HysteresisQuery: Alignment Graph has 10 vertices
# 2021-03-26 11:38:36.377617:
# HysteresisQuery: Alignment Graph has 12 edges
# 2021-03-26 11:38:36.379933:
# HysteresisQuery: Reachability computed.
# 2021-03-26 11:38:36.381253:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.381760:
# HysteresisQuery(98)
# 2021-03-26 11:38:36.384293:
# SingleGeneQuery(98)
# 2021-03-26 11:38:36.391783:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.394539:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.395392:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.397586:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.398198:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.401013:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.404875:
# HysteresisQuery(99)
# 2021-03-26 11:38:36.406339:
# SingleGeneQuery(99)
# 2021-03-26 11:38:36.409855:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.411116:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.413838:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.415291:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.416624:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.423828:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.431357:
# HysteresisQuery(100)
# 2021-03-26 11:38:36.432917:
# SingleGeneQuery(100)
# 2021-03-26 11:38:36.434976:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.438939:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.443792:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.465370:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.491172:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.495383:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.496809:
# HysteresisQuery(101)
# 2021-03-26 11:38:36.498581:
# SingleGeneQuery(101)
# 2021-03-26 11:38:36.499688:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.512471:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.514170:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.517086:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.517935:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.521333:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.523472:
# HysteresisQuery(102)
# 2021-03-26 11:38:36.526494:
# SingleGeneQuery(102)
# 2021-03-26 11:38:36.529447:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.533001:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.534373:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.537204:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.543325:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.544978:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.546260:
# HysteresisQuery(103)
# 2021-03-26 11:38:36.548679:
# SingleGeneQuery(103)
# 2021-03-26 11:38:36.552539:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.558641:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.564732:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.568323:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.570559:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.572088:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.575126:
# HysteresisQuery(104)
# 2021-03-26 11:38:36.576559:
# SingleGeneQuery(104)
# 2021-03-26 11:38:36.578597:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.579909:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.583681:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.588808:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.590108:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.590880:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.594920:
# HysteresisQuery(105)
# 2021-03-26 11:38:36.597888:
# SingleGeneQuery(105)
# 2021-03-26 11:38:36.598736:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.602384:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.603918:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.606779:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.613280:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.617505:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.619885:
# HysteresisQuery(106)
# 2021-03-26 11:38:36.621069:
# SingleGeneQuery(106)
# 2021-03-26 11:38:36.623982:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.625403:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.626696:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.628129:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.629215:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.630132:
# HysteresisQuery: Returning.
# 2021-03-26 11:38:36.630939:
# HysteresisQuery(107)
# 2021-03-26 11:38:36.631629:
# SingleGeneQuery(107)
# 2021-03-26 11:38:36.636695:
# SingleGeneQuery: SQL statement executed
# 2021-03-26 11:38:36.639245:
# SingleGeneQuery: Q constructed
# 2021-03-26 11:38:36.642713:
# SingleGeneQuery: graph constructed
# 2021-03-26 11:38:36.647116:
# SingleGeneQuery: graph attributes emplaced
# 2021-03-26 11:38:36.649442:
# HysteresisQuery: Search Graph Constructed.
# 2021-03-26 11:38:36.650650:
# HysteresisQuery: Returning.
# [False, False, False, False, False, False, False, False, False, False]
